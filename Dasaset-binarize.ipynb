# %% [markdown]
# # Find mapping for reservoir using binarizer

# %% [markdown]
# This notebook take an input dataset for regression problem and binarize the input to be fed to an AMN reservoir. The code make use of RandomForestRegressor to rank the features (feature_importance) and find the mapping to the reservoir input.

# %% [markdown]
# ## Utilities (run this cell first)

# %%
# Run this cell first 

def input_binarize(parameter, thr, verbose=False):
    # Transforms the feature matrix parameter.X into a matrix Xt 
    # using RandomForestRegressor
    # If the number of desired features k is greater than 
    # the number of original features m,  additional features 
    # are generated duplicating features.
    # Parameters:
    # thr: The number threshold foe binarization
    # Returns: A binary version of the transformed feature matrix paramater.X.
    from Library.Build_Model import rank_feature_by_permutation_importance
    from sklearn.preprocessing import Binarizer
    
    def rank_feature(X, y, regression):
        # Rank features based on permutation_importance
        # using random forest regressor
        if regression:
            model = RandomForestRegressor(n_estimators=100, random_state=42)
        else:
            model = RandomForestClassifier(n_estimators=100, random_state=42)
            
        model.fit(X, y)
        
        # Compute permutation importance
        perm_importance = permutation_importance(model, X, y, n_repeats=10, random_state=42)
        
        # Create a dataframe to hold feature names and their permutation importance scores
        feature_names = list(range(X.shape[1]))
        perm_importance_df = pd.DataFrame({
            'Feature': feature_names,
            'Importance': perm_importance.importances_mean
            })
        
        # Sort by importance
        perm_importance_df = perm_importance_df.sort_values(by='Importance', ascending=False)
        sorted_features = perm_importance_df['Feature'].tolist()
        
        return sorted_features

    X, Xt, k = parameter.X, np.copy(parameter.X), parameter.res.X.shape[1]

    # Add columns to increase the number of features to k
    while Xt.shape[1] < k:
        i = np.random.randint(0, Xt.shape[1])
        Xt = np.concatenate((Xt, Xt[:,i].reshape(-1,1)), axis=1)
        
    # Binarize data
    scaler = MinMaxScaler()
    Xt = scaler.fit_transform(Xt)  
    binarizer = Binarizer(threshold=thr)
    Xb = binarizer.fit_transform(Xt)

    # Rank the features of both binarized array and reservoir
    lb = rank_feature(Xt, parameter.Y.ravel())
    lr = rank_feature(parameter.res.X, parameter.res.Y.ravel())
    if verbose:
        print('reservoir:', lr)
        print('problem  :', lb)
        
    # Ranked features one-to-one mapping 
    Xbr = np.zeros((Xb.shape[0], parameter.res.X.shape[1]))
    for i in range(len(lr)):
        Xbr[:,lr[i]] = Xb[:,lb[i]]
            
    return Xbr
        
def reservoir_binarize(reservoirfile, X, Y, mode='AMN-phenotype',
                       n_hidden_post=0,
                       train_rate=1.0e-3, batch_size=10, xfold=5, epochs=100, 
                       niter=1, t0=0.1, t1=1, dt=0.1, verbose=False):
    # Search best threshold for binarizer on binarized input
    
    from Library.Build_Reservoir import RC_Model
    from Library.Build_Model import train_evaluate_model, evaluate_model, model_input
    from sklearn.metrics import r2_score, accuracy_score

    batch_size = 100 if X.shape[0] > 1000 else 10    
    best_t, best_r2, failure = -1, -1000, 10
     
    for t in np.arange(t0, t1, dt):
        # Create model
        model = RC_Model(mode=mode,
                reservoirfile=reservoirfile, X=X, Y=Y,
                n_hidden_prior=-1, n_hidden_post=n_hidden_post,
                activation_post='relu',
                batch_size=batch_size,
                epochs=epochs, train_rate=train_rate, 
                xfold=xfold, niter=niter, verbose=verbose)
        # binarize the input
        model.X = input_binarize(model, t, verbose=verbose)
        # Train and evaluate
        _, pred, _, _ = train_evaluate_model(model, failure=failure, verbose=verbose)
        r2 = r2_score(Y, pred[:, 0], multioutput='variance_weighted')
        if verbose:
            print(f'threshold: {t:.2f} q2: {r2:.3f}')
        if r2 > best_r2:
            best_r2 = r2
            best_t = t
            best_model = model
    if verbose:
        print(f'Best threshold: {best_t:.2f} q2: {best_r2:.3f}')
    
    return best_model, best_t, best_r2

def write_model_binarize(trainingfile, model, verbose=True):  
    # Write file with X in binary format
    from Library.Build_Dataset import get_minmed_varmed_ko
    
    medium = model.res.medium
    minmed, varmed, ko = get_minmed_varmed_ko(medium)    
    medium = list(varmed.keys())
    medium.append('Y_true')
    H = np.asarray(medium)
    D = np.concatenate((model.X, model.Y), axis=1)
    write_csv(trainingfile, H, D)

# %% [markdown]
# ## Main code

# %%
# Search the best mapping between an input file and reservoir input

from Library.Import import *

DIRECTORY = './'
problems = [
    'raw_geographical_origin_of_music', # 0
    'raw_pumadyn32nh',
    'raw_white_wine', # 2
    'raw_kin8nm',
    'raw_cars', # 4
    'raw_airfoil_self_noise', #5
    'raw_QSAR_fish_toxicity', # 6
    'raw_space_ga',
    'raw_concrete_compressive_strength', # 8
    'raw_grid_stability',
    'raw_miami_housing', # 10
    'raw_cpu_activity', # 11
    'raw_naval_propulsion_plant',
    'raw_energy_efficiency' # 13
]

species = [ 
    'e_coli_core', #0
    'iEK1008', 
    'iIT341', #2
    'iJN1463', 
    'iML1515', #4
    'iMM904',
    'iPC815', #6
    'iYO844',
    'iYS1720', 
    'iYS854', # 9
    'iML1515EXP', #10
]

seed = 1
np.random.seed(seed=seed)
mode = 'AMN_phenotype'
precision = 0
n_hidden_post = 0 
xfold = 5
epochs = 100 
niter = 1 # 0 for full xfold cv
train_rate = 1.0e-4 # 1.0e-4 for white wine may be 1.0e-3 otherwise

for i in [10]: # list(range(11))
    s = species[i]
    reservoirname = f'{s}_train_AMN_QP'
    reservoirfile = f'{DIRECTORY}Reservoir/{reservoirname}' 
    for j in [2, 3, 4, 5, 6, 7, 8, 9, 11, 13]: # list(range(14)):
        problem = problems[j].split('.')[0]
        trainingfile = f'{DIRECTORY}Dataset_input/Dataset_open_ML/Regression/{problem}'
        resultfile = f'{DIRECTORY}Result/{problem}_{s}_{mode}_{str(precision)}'
        H, X, Y = read_XY(trainingfile, nY=1, scaling='XY')
        start_time = time.time()
        # search treshold between 0.1 and 0.9
        t0, t1, dt = 0.1, 1.0, 0.1
        model, threshold, q2 = reservoir_binarize(reservoirfile, X, Y, mode=mode,
                            n_hidden_post=n_hidden_post,
                            train_rate=train_rate, 
                            xfold=xfold, epochs=epochs, niter=niter, 
                            t0=t0, t1=t1, dt=dt, verbose=True)
        # search around the threshold
        t0, t1, dt = threshold-0.01, threshold+0.02, 0.01
        model, threshold, q2 = reservoir_binarize(reservoirfile, X, Y, mode=mode,
                            n_hidden_post=n_hidden_post,
                            train_rate=train_rate, 
                            xfold=xfold, epochs=epochs, niter=niter, 
                            t0=t0, t1=t1, dt=dt, verbose=True)
        delta_time = time.time() - start_time
        print(f'{problem} {s} Threshold {threshold:.2f} Q2: {q2:.3f} cpu time {delta_time:.2f}')
        trainingfile = f'{trainingfile}_{s}_binary' 
        write_model_binarize(trainingfile, model, verbose=True)
# Out:
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [10,
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [10, 1, 20, 5, 25, 0, 2, 13, 8, 11, 18, 7, 9, 12, 24, 15, 16, 3, 27, 17, 19, 4, 26, 14, 22, 21, 23, 6]
# RC scaler: MinMaxScaler()
# RC input shape:((4898, 28), (4898, 1))
# -------train (3918, 28) (3918, 2)
# -------test  (980, 28) (980, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 123/123 [==============================] - 0s 915us/step
# Failure number: 1 R2: -10.752781616947694
# 123/123 [==============================] - 0s 912us/step
# Failure number: 2 R2: -0.0059530918707844105
# 123/123 [==============================] - 0s 1ms/step
# Failure number: 3 R2: -0.005173008647399113
# 123/123 [==============================] - 0s 963us/step
# Failure number: 4 R2: -0.004588427326094102
# 123/123 [==============================] - 0s 1ms/step
# Failure number: 5 R2: -0.005671750025661115
# 123/123 [==============================] - 0s 1ms/step
# Failure number: 6 R2: -0.005357485623890712
# 123/123 [==============================] - 0s 967us/step
# Failure number: 7 R2: -10.752781616947694
# 123/123 [==============================] - 0s 928us/step
# Failure number: 8 R2: -10.752781616947694
# 123/123 [==============================] - 0s 1ms/step
# Failure number: 9 R2: -0.00587006858514294
# 123/123 [==============================] - 0s 1ms/step
# Failure number: 10 R2: -0.004626061901588985
# 123/123 [==============================] - 0s 1ms/step
# 31/31 [==============================] - 0s 1ms/step
# train = -0.01 test = -0.00 loss-train = -1.000000 loss-test = -1.000000
# 154/154 [==============================] - 0s 1ms/step
# threshold: 0.90 q2: -0.004
# Best threshold: 0.40 q2: 0.146
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [1, 8, 4, 7, 0, 9, 24, 27, 25, 3, 14, 23, 19, 22, 26, 2, 10, 16, 17, 11, 6, 5, 21, 15, 18, 20, 12, 13]
# RC scaler: MinMaxScaler()
# RC input shape:((4898, 28), (4898, 1))
# -------train (3918, 28) (3918, 2)
# -------test  (980, 28) (980, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 123/123 [==============================] - 0s 998us/step
# Failure number: 1 R2: -10.443474519485404
# 123/123 [==============================] - 0s 1ms/step
# 123/123 [==============================] - 0s 975us/step
# 31/31 [==============================] - 0s 1ms/step
# train = 0.14 test = 0.15 loss-train = -1.000000 loss-test = -1.000000
# 154/154 [==============================] - 0s 1ms/step
# threshold: 0.39 q2: 0.143
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [10, 1, 7, 0, 18, 3, 16, 11, 5, 4, 13, 22, 6, 20, 19, 9, 12, 2, 21, 25, 26, 27, 14, 15, 24, 8, 17, 23]
# RC scaler: MinMaxScaler()
# RC input shape:((4898, 28), (4898, 1))
# -------train (3918, 28) (3918, 2)
# -------test  (980, 28) (980, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 123/123 [==============================] - 0s 977us/step
# Failure number: 1 R2: -10.543115666602652
# 123/123 [==============================] - 0s 1ms/step
# 123/123 [==============================] - 0s 1ms/step
# 31/31 [==============================] - 0s 1ms/step
# train = 0.14 test = 0.12 loss-train = -1.000000 loss-test = -1.000000
# 154/154 [==============================] - 0s 1ms/step
# threshold: 0.40 q2: 0.135
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [10, 1, 5, 7, 2, 3, 20, 0, 17, 21, 4, 13, 25, 6, 24, 15, 11, 9, 16, 23, 19, 27, 8, 12, 22, 26, 18, 14]
# RC scaler: MinMaxScaler()
# RC input shape:((4898, 28), (4898, 1))
# -------train (3918, 28) (3918, 2)
# -------test  (980, 28) (980, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 123/123 [==============================] - 0s 949us/step
# Failure number: 1 R2: -10.515336412845874
# 123/123 [==============================] - 0s 971us/step
# 123/123 [==============================] - 0s 1ms/step
# 31/31 [==============================] - 0s 1ms/step
# train = 0.13 test = 0.12 loss-train = -1.000000 loss-test = -1.000000
# 154/154 [==============================] - 0s 1ms/step
# threshold: 0.41 q2: 0.126
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [1, 10, 25, 5, 8, 6, 7, 21, 0, 17, 27, 22, 15, 13, 14, 3, 24, 20, 23, 4, 12, 9, 11, 18, 2, 26, 16, 19]
# RC scaler: MinMaxScaler()
# RC input shape:((4898, 28), (4898, 1))
# -------train (3918, 28) (3918, 2)
# -------test  (980, 28) (980, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 123/123 [==============================] - 0s 1ms/step
# Failure number: 1 R2: -0.0024051227593915314
# 123/123 [==============================] - 0s 955us/step
# 123/123 [==============================] - 0s 1ms/step
# 31/31 [==============================] - 0s 1ms/step
# train = 0.13 test = 0.14 loss-train = -1.000000 loss-test = -1.000000
# 154/154 [==============================] - 0s 930us/step
# threshold: 0.42 q2: 0.135
# Best threshold: 0.39 q2: 0.143
# raw_white_wine iYS854 Threshold 0.39 Q2: 0.143 cpu time 1030.27
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [4, 6, 12, 2, 3, 5, 27, 20, 7, 25, 18, 0, 10, 22, 26, 13, 11, 17, 15, 1, 16, 14, 21, 24, 9, 19, 8, 23]
# RC scaler: MinMaxScaler()
# RC input shape:((8192, 28), (8192, 1))
# -------train (6553, 28) (6553, 2)
# -------test  (1639, 28) (1639, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 205/205 [==============================] - 0s 1ms/step
# Failure number: 1 R2: -6.488572098500238
# 205/205 [==============================] - 0s 983us/step
# Failure number: 2 R2: -6.488572098500238
# 205/205 [==============================] - 0s 1ms/step
# Failure number: 3 R2: -6.488572098500238
# 205/205 [==============================] - 0s 1ms/step
# 205/205 [==============================] - 0s 1ms/step
# 52/52 [==============================] - 0s 1ms/step
# train = 0.05 test = 0.05 loss-train = -1.000000 loss-test = -1.000000
# 256/256 [==============================] - 0s 1ms/step
# threshold: 0.10 q2: 0.049
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [2, 3, 6, 20, 4, 18, 25, 14, 10, 21, 8, 7, 17, 5, 12, 22, 0, 13, 16, 23, 24, 11, 27, 15, 26, 9, 1, 19]
# RC scaler: MinMaxScaler()
# RC input shape:((8192, 28), (8192, 1))
# -------train (6553, 28) (6553, 2)
# -------test  (1639, 28) (1639, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 205/205 [==============================] - 0s 1ms/step
# 205/205 [==============================] - 0s 1ms/step
# 52/52 [==============================] - 0s 1ms/step
# train = 0.08 test = 0.08 loss-train = -1.000000 loss-test = -1.000000
# 256/256 [==============================] - 0s 1ms/step
# threshold: 0.20 q2: 0.078
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [4, 5, 3, 0, 17, 6, 11, 22, 15, 7, 13, 12, 23, 26, 14, 25, 2, 16, 24, 10, 21, 27, 9, 20, 18, 1, 19, 8]
# RC scaler: MinMaxScaler()
# RC input shape:((8192, 28), (8192, 1))
# -------train (6553, 28) (6553, 2)
# -------test  (1639, 28) (1639, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 205/205 [==============================] - 0s 1ms/step
# Failure number: 1 R2:

# RC scaler: MinMaxScaler()
# RC input shape:((392, 28), (392, 1))
# -------train (313, 28) (313, 2)
# -------test  (79, 28) (79, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 10/10 [==============================] - 0s 1ms/step
# Failure number: 1 R2: -0.5573061659657617
# 10/10 [==============================] - 0s 1ms/step
# 10/10 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# train = 0.38 test = 0.39 loss-train = -1.000000 loss-test = -1.000000
# 13/13 [==============================] - 0s 1ms/step
# threshold: 0.30 q2: 0.386
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [2, 0, 21, 24, 3, 14, 11, 4, 25, 22, 15, 13, 10, 20, 18, 5, 26, 23, 16, 6, 19, 9, 7, 27, 17, 8, 12, 1]
# RC scaler: MinMaxScaler()
# RC input shape:((392, 28), (392, 1))
# -------train (313, 28) (313, 2)
# -------test  (79, 28) (79, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 10/10 [==============================] - 0s 1ms/step
# Failure number: 1 R2: -0.5369132781124548
# 10/10 [==============================] - 0s 1ms/step
# 10/10 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# train = 0.24 test = 0.22 loss-train = -1.000000 loss-test = -1.000000
# 13/13 [==============================] - 0s 1ms/step
# threshold: 0.40 q2: 0.233
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [27, 2, 14, 3, 22, 0, 21, 15, 8, 5, 6, 12, 23, 11, 25, 26, 24, 18, 4, 19, 10, 9, 17, 16, 20, 13, 1, 7]
# RC scaler: MinMaxScaler()
# RC input shape:((392, 28), (392, 1))
# -------train (313, 28) (313, 2)
# -------test  (79, 28) (79, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 10/10 [==============================] - 0s 1ms/step
# Failure number: 1 R2: -0.5224706557795362
# 10/10 [==============================] - 0s 1ms/step
# 10/10 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# train = 0.22 test = 0.24 loss-train = -1.000000 loss-test = -1.000000
# 13/13 [==============================] - 0s 1ms/step
# threshold: 0.50 q2: 0.225
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [2, 13, 23, 3, 10, 26, 7, 24, 21, 16, 5, 25, 14, 4, 20, 15, 8, 12, 18, 11, 0, 9, 19, 6, 1, 22, 17, 27]
# RC scaler: MinMaxScaler()
# RC input shape:((392, 28), (392, 1))
# -------train (313, 28) (313, 2)
# -------test  (79, 28) (79, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 10/10 [==============================] - 0s 1ms/step
# 10/10 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# train = 0.15 test = 0.14 loss-train = -1.000000 loss-test = -1.000000
# 13/13 [==============================] - 0s 1ms/step
# threshold: 0.60 q2: 0.147
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [17, 9, 21, 2, 4, 16, 12, 5, 22, 3, 10, 0, 11, 15, 19, 14, 18, 6, 8, 7, 25, 24, 26, 1, 23, 13, 20, 27]
# RC scaler: MinMaxScaler()
# RC input shape:((392, 28), (392, 1))
# -------train (313, 28) (313, 2)
# -------test  (79, 28) (79, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 10/10 [==============================] - 0s 1ms/step
# 10/10 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# train = 0.08 test = 0.07 loss-train = -1.000000 loss-test = -1.000000
# 13/13 [==============================] - 0s 1ms/step
# threshold: 0.70 q2: 0.080
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [2, 12, 3, 24, 21, 5, 0, 8, 22, 4, 26, 17, 25, 11, 23, 9, 16, 19, 7, 1, 13, 10, 14, 27, 18, 6, 15, 20]
# RC scaler: MinMaxScaler()
# RC input shape:((392, 28), (392, 1))
# -------train (313, 28) (313, 2)
# -------test  (79, 28) (79, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 10/10 [==============================] - 0s 939us/step
# 10/10 [==============================] - 0s 868us/step
# 3/3 [==============================] - 0s 1ms/step
# train = 0.15 test = 0.17 loss-train = -1.000000 loss-test = -1.000000
# 13/13 [==============================] - 0s 1ms/step
# threshold: 0.80 q2: 0.152
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [2, 26, 0, 7, 19, 22, 23, 5, 14, 18, 9, 13, 10, 6, 4, 12, 3, 15, 1, 25, 8, 21, 16, 11, 27, 24, 20, 17]
# RC scaler: MinMaxScaler()
# RC input shape:((392, 28), (392, 1))
# -------train (313, 28) (313, 2)
# -------test  (79, 28) (79, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 10/10 [==============================] - 0s 1ms/step
# Failure number: 1 R2: -0.5132957292506053
# 10/10 [==============================] - 0s 1ms/step
# 10/10 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# train = 0.05 test = 0.08 loss-train = -1.000000 loss-test = -1.000000
# 13/13 [==============================] - 0s 1ms/step
# threshold: 0.90 q2: 0.058
# Best threshold: 0.20 q2: 0.388
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [17, 2, 12, 0, 11, 26, 8, 3, 27, 5, 20, 21, 9, 4, 16, 13, 6, 10, 7, 24, 18, 19, 23, 25, 14, 1, 22, 15]
# RC scaler: MinMaxScaler()
# RC input shape:((392, 28), (392, 1))
# -------train (313, 28) (313, 2)
# -------test  (79, 28) (79, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 10/10 [==============================] - 0s 1ms/step
# 10/10 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# train = 0.35 test = 0.40 loss-train = -1.000000 loss-test = -1.000000
# 13/13 [==============================] - 0s 1ms/step
# threshold: 0.19 q2: 0.364
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [5, 4, 13, 21, 14, 7, 27, 3, 16, 19, 26, 11, 2, 25, 8, 22, 6, 18, 12, 15, 23, 10, 0, 24, 9, 20, 17, 1]
# RC scaler: MinMaxScaler()
# RC input shape:((392, 28), (392, 1))
# -------train (313, 28) (313, 2)
# -------test  (79, 28) (79, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 10/10 [==============================] - 0s 1ms/step
# 10/10 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# train = 0.35 test = 0.47 loss-train = -1.000000 loss-test = -1.000000
# 13/13 [==============================] - 0s 1ms/step
# threshold: 0.20 q2: 0.374
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [3, 13, 7, 27, 15, 23, 2, 19, 5, 0, 22, 4, 12, 17, 18, 8, 25, 6, 24, 10, 1, 11, 21, 26, 14, 16, 9, 20]
# RC scaler: MinMaxScaler()
# RC input shape:((392, 28), (392, 1))
# -------train (313, 28) (313, 2)
# -------test  (79, 28) (79, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 10/10 [==============================] - 0s 1ms/step
# Failure number: 1 R2: -0.5244620540608314
# 10/10 [==============================] - 0s 1ms/step
# 10/10 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# train = 0.36 test = 0.36 loss-train = -1.000000 loss-test = -1.000000
# 13/13 [==============================] - 0s 1ms/step
# threshold: 0.21 q2: 0.360
# Best threshold: 0.20 q2: 0.374
# raw_cars iYS854 Threshold 0.20 Q2: 0.374 cpu time 632.31
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [4, 3, 20, 27, 15, 16, 2, 22, 7, 18, 23, 17, 12, 8, 10, 6, 13, 9, 25, 1, 14, 0, 11, 26, 21, 24, 19, 5]
# RC scaler: MinMaxScaler()
# RC input shape:((1503, 28), (1503, 1))
# -------train (1202, 28) (1202, 2)
# -------test  (301, 28) (301, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 38/38 [==============================] - 0s 1ms/step
# Failure number: 1 R2: -9.641614703378842
# 38/38 [==============================] - 0s 1ms/step
# Failure number: 2 R2: -9.641614703378842
# 38/38 [==============================] - 0s 1ms/step
# Failure number: 3 R2: -9.641614703378842
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
# 10/10 [==============================] - 0s 1ms/step
# train = 0.20 test = 0.17 loss-train = -1.000000 loss-test = -1.000000
# 47/47 [==============================] - 0s 1ms/step
# threshold: 0.10 q2: 0.192
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [16, 12, 0, 23, 22, 11, 24, 18, 25, 7, 5, 26, 4, 2, 20, 21, 14, 17, 3, 27, 6, 15, 9, 1, 13, 19, 8, 10]
# RC scaler: MinMaxScaler()
# RC input shape:((1503, 28), (1503, 1))
# -------train (1202, 28) (1202, 2)
# -------test  (301, 28) (301, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 38/38 [==============================] - 0s 1ms/step
# Failure number: 1 R2: -9.27447464314584
# 38/38 [==============================] - 0s 1ms/step
# Failure number: 2 R2: -9.27447464314584
# 38/38 [==============================] - 0s 1ms/step
# Failure number: 3 R2: -9.27447464314584
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 986us/step
# 10/10 [==============================] - 0s 1ms/step
# train = 0.24 test = 0.13 loss-train = -1.000000 loss-test = -1.000000
# 47/47 [==============================] - 0s 1ms/step
# threshold: 0.20 q2: 0.221
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [0, 3, 26, 10, 19, 17, 4, 20, 25, 27, 1, 23, 24, 13, 12, 14, 8, 16, 7, 11, 6, 22, 2, 15, 9, 18, 21, 5]
# RC scaler: MinMaxScaler()
# RC input shape:((1503, 28), (1503, 1))
# -------train (1202, 28) (1202, 2)
# -------test  (301, 28) (301, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 38/38 [==============================] - 0s 1ms/step
# Failure number: 1 R2: -0.2979696813717345
# 38/38 [==============================] - 0s 1ms/step
# Failure number: 2 R2: -9.690885398890407
# 38/38 [==============================] - 0s 1ms/step
# Failure number: 3 R2: -9.690885398890407
# 38/38 [==============================] - 0s 938us/step
# 38/38 [==============================] - 0s 1ms/step
# 10/10 [==============================] - 0s 1ms/step
# train = 0.13 test = 0.13 loss-train = -1.000000 loss-test = -1.000000
# 47/47 [==============================] - 0s 1ms/step
# threshold: 0.30 q2: 0.132
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# ...
# problem  : [17, 23, 20, 18, 24, 22, 2, 4, 15, 6, 16, 3, 7, 14, 8, 21, 25, 19, 10, 0, 27, 9, 1, 11, 5, 26, 13, 12]
# RC scaler: MinMaxScaler()
# RC input shape:((8192, 28), (8192, 1))
# -------train (6553, 28) (6553, 2)
# -------test  (1639, 28) (1639, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 205/205 [==============================] - 0s 947us/step
# Failure number: 1 R2: -21.342522788874277
# 205/205 [==============================] - 0s 915us/step
# 205/205 [==============================] - 0s 1ms/step
# 52/52 [==============================] - 0s 1ms/step
# train = 0.66 test = 0.64 loss-train = -1.000000 loss-test = -1.000000
# 256/256 [==============================] - 0s 1ms/step
# threshold: 0.41 q2: 0.654
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [18, 20, 17, 23, 2, 4, 15, 16, 7, 19, 6, 24, 8, 21, 27, 3, 14, 26, 10, 5, 0, 25, 1, 9, 13, 22, 11, 12]
# RC scaler: MinMaxScaler()
# RC input shape:((8192, 28), (8192, 1))
# -------train (6553, 28) (6553, 2)
# -------test  (1639, 28) (1639, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 205/205 [==============================] - 0s 1ms/step
# 205/205 [==============================] - 0s 1ms/step
# 52/52 [==============================] - 0s 1ms/step
# train = 0.38 test = 0.41 loss-train = -1.000000 loss-test = -1.000000
# 256/256 [==============================] - 0s 1ms/step
# threshold: 0.42 q2: 0.387
# Best threshold: 0.39 q2: 0.765
# raw_cpu_activity iYS854 Threshold 0.39 Q2: 0.765 cpu time 1389.06
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [6, 15, 10, 8, 19, 18, 14, 21, 0, 1, 2, 9, 23, 13, 22, 4, 27, 11, 25, 3, 5, 17, 7, 20, 26, 12, 16, 24]
# RC scaler: MinMaxScaler()
# RC input shape:((768, 28), (768, 1))
# -------train (614, 28) (614, 2)
# -------test  (154, 28) (154, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 20/20 [==============================] - 0s 1ms/step
# Failure number: 1 R2: -2.5769156767701826
# 20/20 [==============================] - 0s 1ms/step
# 20/20 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 1ms/step
# train = 0.46 test = 0.42 loss-train = -1.000000 loss-test = -1.000000
# 24/24 [==============================] - 0s 1ms/step
# threshold: 0.10 q2: 0.450
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [6, 9, 16, 0, 12, 15, 24, 4, 23, 7, 17, 8, 21, 25, 27, 22, 1, 5, 14, 2, 19, 26, 18, 11, 10, 20, 13, 3]
# RC scaler: MinMaxScaler()
# RC input shape:((768, 28), (768, 1))
# -------train (614, 28) (614, 2)
# -------test  (154, 28) (154, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 20/20 [==============================] - 0s 1ms/step
# 20/20 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 2ms/step
# train = 0.70 test = 0.70 loss-train = -1.000000 loss-test = -1.000000
# 24/24 [==============================] - 0s 1ms/step
# threshold: 0.20 q2: 0.700
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [9, 22, 4, 0, 18, 24, 16, 15, 23, 13, 6, 2, 17, 8, 20, 14, 19, 21, 27, 10, 7, 11, 25, 26, 1, 5, 12, 3]
# RC scaler: MinMaxScaler()
# RC input shape:((768, 28), (768, 1))
# -------train (614, 28) (614, 2)
# -------test  (154, 28) (154, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 20/20 [==============================] - 0s 1ms/step
# 20/20 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 1ms/step
# train = 0.77 test = 0.77 loss-train = -1.000000 loss-test = -1.000000
# 24/24 [==============================] - 0s 1ms/step
# threshold: 0.30 q2: 0.773
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [12, 1, 17, 22, 9, 16, 6, 25, 15, 21, 13, 24, 0, 4, 2, 18, 27, 8, 26, 11, 7, 20, 5, 14, 10, 23, 19, 3]
# RC scaler: MinMaxScaler()
# RC input shape:((768, 28), (768, 1))
# -------train (614, 28) (614, 2)
# -------test  (154, 28) (154, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 20/20 [==============================] - 0s 1ms/step
# Failure number: 1 R2: -2.6359327227983473
# 20/20 [==============================] - 0s 1ms/step
# Failure number: 2 R2: -2.6359327227983473
# 20/20 [==============================] - 0s 1ms/step
# Failure number: 3 R2: -2.6359327227983473
# 20/20 [==============================] - 0s 1ms/step
# 20/20 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 2ms/step
# train = 0.83 test = 0.84 loss-train = -1.000000 loss-test = -1.000000
# 24/24 [==============================] - 0s 1ms/step
# threshold: 0.40 q2: 0.833
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [0, 4, 1, 2, 24, 3, 25, 6, 15, 21, 22, 10, 26, 20, 13, 27, 19, 7, 23, 9, 18, 11, 5, 17, 16, 12, 8, 14]
# RC scaler: MinMaxScaler()
# RC input shape:((768, 28), (768, 1))
# -------train (614, 28) (614, 2)
# -------test  (154, 28) (154, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 20/20 [==============================] - 0s 1ms/step
# 20/20 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 1ms/step
# train = 0.25 test = 0.15 loss-train = -1.000000 loss-test = -1.000000
# 24/24 [==============================] - 0s 1ms/step
# threshold: 0.50 q2: 0.227
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [24, 4, 0, 8, 16, 6, 27, 1, 20, 3, 11, 23, 18, 2, 22, 17, 12, 7, 15, 21, 10, 14, 25, 19, 5, 9, 13, 26]
# RC scaler: MinMaxScaler()
# RC input shape:((768, 28), (768, 1))
# -------train (614, 28) (614, 2)
# -------test  (154, 28) (154, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 20/20 [==============================] - 0s 1ms/step
# Failure number: 1 R2: -2.5052760193433183
# 20/20 [==============================] - 0s 1ms/step
# 20/20 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 1ms/step
# train = 0.67 test = 0.61 loss-train = -1.000000 loss-test = -1.000000
# 24/24 [==============================] - 0s 1ms/step
# threshold: 0.60 q2: 0.663
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [0, 17, 25, 6, 15, 1, 24, 22, 20, 16, 13, 27, 18, 14, 9, 2, 4, 26, 7, 19, 12, 3, 10, 11, 8, 23, 5, 21]
# RC scaler: MinMaxScaler()
# RC input shape:((768, 28), (768, 1))
# -------train (614, 28) (614, 2)
# -------test  (154, 28) (154, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 20/20 [==============================] - 0s 1ms/step
# 20/20 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 1ms/step
# train = 0.75 test = 0.75 loss-train = -1.000000 loss-test = -1.000000
# 24/24 [==============================] - 0s 1ms/step
# threshold: 0.70 q2: 0.749
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [4, 26, 18, 0, 20, 13, 1, 19, 6, 9, 10, 23, 3, 22, 12, 7, 8, 17, 27, 5, 2, 16, 25, 11, 14, 21, 24, 15]
# RC scaler: MinMaxScaler()
# RC input shape:((768, 28), (768, 1))
# -------train (614, 28) (614, 2)
# -------test  (154, 28) (154, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 20/20 [==============================] - 0s 1ms/step
# 20/20 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 1ms/step
# train = 0.75 test = 0.76 loss-train = -1.000000 loss-test = -1.000000
# 24/24 [==============================] - 0s 1ms/step
# threshold: 0.80 q2: 0.753
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [0, 6, 22, 9, 17, 16, 14, 4, 7, 2, 1, 21, 18, 11, 24, 26, 10, 8, 27, 13, 20, 25, 12, 19, 23, 5, 3, 15]
# RC scaler: MinMaxScaler()
# RC input shape:((768, 28), (768, 1))
# -------train (614, 28) (614, 2)
# -------test  (154, 28) (154, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 20/20 [==============================] - 0s 1ms/step
# Failure number: 1 R2: -2.571431475377609
# 20/20 [==============================] - 0s 1ms/step
# 20/20 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 1ms/step
# train = 0.77 test = 0.76 loss-train = -1.000000 loss-test = -1.000000
# 24/24 [==============================] - 0s 1ms/step
# threshold: 0.90 q2: 0.766
# Best threshold: 0.40 q2: 0.833
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [0, 21, 4, 9, 24, 1, 2, 23, 22, 26, 27, 11, 16, 13, 20, 8, 12, 6, 19, 14, 5, 10, 17, 25, 15, 18, 7, 3]
# RC scaler: MinMaxScaler()
# RC input shape:((768, 28), (768, 1))
# -------train (614, 28) (614, 2)
# -------test  (154, 28) (154, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 20/20 [==============================] - 0s 1ms/step
# 20/20 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 1ms/step
# train = 0.82 test = 0.75 loss-train = -1.000000 loss-test = -1.000000
# 24/24 [==============================] - 0s 984us/step
# threshold: 0.39 q2: 0.809
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [6, 0, 4, 27, 18, 24, 8, 7, 2, 15, 1, 14, 22, 16, 10, 3, 9, 19, 23, 11, 12, 25, 5, 21, 26, 20, 17, 13]
# RC scaler: MinMaxScaler()
# RC input shape:((768, 28), (768, 1))
# -------train (614, 28) (614, 2)
# -------test  (154, 28) (154, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 20/20 [==============================] - 0s 1ms/step
# 20/20 [==============================] - 0s 983us/step
# 5/5 [==============================] - 0s 1ms/step
# train = 0.73 test = 0.76 loss-train = -1.000000 loss-test = -1.000000
# 24/24 [==============================] - 0s 1ms/step
# threshold: 0.40 q2: 0.738
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [16, 20, 0, 9, 12, 6, 4, 13, 21, 24, 14, 27, 2, 23, 26, 19, 17, 18, 11, 15, 1, 7, 25, 8, 3, 5, 22, 10]
# RC scaler: MinMaxScaler()
# RC input shape:((768, 28), (768, 1))
# -------train (614, 28) (614, 2)
# -------test  (154, 28) (154, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 20/20 [==============================] - 0s 1ms/step
# 20/20 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 2ms/step
# train = 0.87 test = 0.85 loss-train = -1.000000 loss-test = -1.000000
# 24/24 [==============================] - 0s 1ms/step
# threshold: 0.41 q2: 0.868
# number of reactions: 2086=2086
# number of metabolites: 1335
# filtered measurements size: 1
# Reservoir matrices shapes for AMN-phenotype W (2,) bias (2,)
# reservoir: [0, 27, 1, 19, 24, 18, 10, 14, 8, 5, 4, 6, 16, 2, 9, 11, 21, 13, 12, 3, 17, 25, 22, 20, 15, 26, 7, 23]
# problem  : [6, 0, 16, 21, 17, 27, 12, 1, 23, 20, 13, 2, 19, 3, 4, 8, 25, 24, 7, 15, 11, 9, 26, 18, 14, 5, 10, 22]
# RC scaler: MinMaxScaler()
# RC input shape:((768, 28), (768, 1))
# -------train (614, 28) (614, 2)
# -------test  (154, 28) (154, 2)
# ----------------------------------- RC
# Res IO (None, 28) (None, 2086)
# Dense layer n_hidden: 0 hidden_dim: -1 input_dim: 2086 output_dim: 1 activation: relu trainable: True
# Post IO (None, 2086) (None, 1)
# 20/20 [==============================] - 0s 1ms/step
# Failure number: 1 R2: -2.5575633080444247
# 20/20 [==============================] - 0s 1ms/step
# 20/20 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 1ms/step
# train = 0.82 test = 0.82 loss-train = -1.000000 loss-test = -1.000000
# 24/24 [==============================] - 0s 2ms/step
# threshold: 0.42 q2: 0.818
# Best threshold: 0.41 q2: 0.868
# raw_energy_efficiency iYS854 Threshold 0.41 Q2: 0.868 cpu time 787.37
