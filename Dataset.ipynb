# %% [markdown]
# # Build datasets for Reservoir Computing

# %% [markdown]
# ## Exchange metabolites list

# %%
# Run cobra on various models

DIRECTORY = './Dataset_input/'

from Library.Import import *
from Library.Build_Dataset import get_objective
import cobra

MEDIA, EXCHANGE = {}, {}
species = [ 
    'e_coli_core', #0
    'iEK1008', 
    'iIT341', #2
    'iJN1463', 
    'iML1515', #4
    'iMM904',
    'iPC815', #6
    'iYO844',
    'iYS1720', 
    'iYS854', # 9
    'iCN718',
    'iNF517',
    'iML1515EXP'
]
for i in [ 11 ]:
    name = species[i]
    cobrafile = f'{DIRECTORY}{name}_duplicated.xml'
    model = cobra.io.read_sbml_model(cobrafile)
    for r in model.medium.keys():
        if r in MEDIA.keys():
            MEDIA[r] = MEDIA[r] + ',' + name
        else:
            MEDIA[r] = name
    nEXCHANGE = 0
    for reaction in model.reactions:
        r = reaction.id
        if '_e' not in r:
            continue
        nEXCHANGE += 1
        if r in EXCHANGE.keys():
            EXCHANGE[r] = EXCHANGE[r] + ',' + name
        else:
            EXCHANGE[r] = name
    
    objective = get_objective(model)
    solution = model.optimize()
    print(f'{name} Medium-size: {len(model.medium.keys())} Exchange reactions: {nEXCHANGE} Objective: {objective} {solution.fluxes[objective]}')

for r in MEDIA.keys():
    print(f'Medium {r} {MEDIA[r]}')
for r in EXCHANGE.keys():
    print(f'Exchange {r} {EXCHANGE[r]}')
# Out:
# iCN718 Medium-size: 119 Exchange reactions: 238 Objective: BIOMASS__3 1.3135912923645483
# Medium EX_tyr__L_e_i iCN718
# Medium EX_val__L_e_i iCN718
# Medium EX_ser__D_e_i iCN718
# Medium EX_orn_e_i iCN718
# Medium EX_ptrc_e_i iCN718
# Medium EX_spmd_e_i iCN718
# Medium EX_co2_e_i iCN718
# Medium EX_na1_e_i iCN718
# Medium EX_no2_e_i iCN718
# Medium EX_o2_e_i iCN718
# Medium EX_urea_e_i iCN718
# Medium EX_chol_e_i iCN718
# Medium EX_adn_e_i iCN718
# Medium EX_cytd_e_i iCN718
# Medium EX_dad_2_e_i iCN718
# Medium EX_dcyt_e_i iCN718
# Medium EX_dgsn_e_i iCN718
# Medium EX_thymd_e_i iCN718
# Medium EX_duri_e_i iCN718
# Medium EX_h_e_i iCN718
# Medium EX_malt_e_i iCN718
# Medium EX_fru_e_i iCN718
# Medium EX_glc__D_e_i iCN718
# Medium EX_glcn__D_e_i iCN718
# Medium EX_mnl_e_i iCN718
# Medium EX_acgam_e_i iCN718
# Medium EX_gsn_e_i iCN718
# Medium EX_uri_e_i iCN718
# Medium EX_csn_e_i iCN718
# Medium EX_xan_e_i iCN718
# Medium EX_ura_e_i iCN718
# Medium EX_taur_e_i iCN718
# Medium EX_etha_e_i iCN718
# Medium EX_sucr_e_i iCN718
# Medium EX_tre_e_i iCN718
# Medium EX_2pg_e_i iCN718
# Medium EX_glyb_e_i iCN718
# Medium EX_bz_e_i iCN718
# Medium EX_3pg_e_i iCN718
# Medium EX_ac_e_i iCN718
# Medium EX_akg_e_i iCN718
# Medium EX_cit_e_i iCN718
# Exchange EX_all__D_e_i iCN718
# Exchange EX_lyx__L_e_i iCN718
# Exchange EX_pyr_e_i iCN718
# Exchange EX_galur_e_i iCN718
# Exchange EX_peamn_e_i iCN718
# Exchange EX_lcts_e_i iCN718

# %%
# Get media
# Minimal medium is composed of metabolites both in the initial strain and duplicated strain
# Variable medium is composed of metabolites in duplicated strain NOT in initial strain

DIRECTORY = './Dataset_input/'

from Library.Import import *
from Library.Build_Dataset import get_objective
import cobra

MEDIA, EXCHANGE = {}, {}
species = [ 
    'e_coli_core', #0
    'iEK1008', 
    'iIT341', #2
    'iJN1463', 
    'iML1515', #4
    'iMM904',
    'iPC815', #6
    'iYO844',
    'iYS1720', 
    'iYS854', # 9
    'iCN718',
    'iNF517',
    'iML1515EXP'
]
for i in [ 11 ]:
    name = species[i]
    cobrafile = f'{DIRECTORY}{name}.xml'  # name of the model 
    model = cobra.io.read_sbml_model(cobrafile)
    for r in model.medium.keys():
        print(name, r)
for i in [ 11 ]:
    name = species[i]
    cobrafile = f'{DIRECTORY}{name}_duplicated.xml'  # name of the model 
    model = cobra.io.read_sbml_model(cobrafile)
    for r in model.medium.keys():
        print(name, r, model.medium[r])
    solution = model.optimize()    
    print(solution.objective_value)
# Out:
# iNF517 EX_4abz_e
# iNF517 EX_ade_e
# iNF517 EX_ala__L_e
# iNF517 EX_arg__L_e
# iNF517 EX_asp__L_e
# iNF517 EX_co2_e
# iNF517 EX_cys__L_e
# iNF517 EX_fe2_e
# iNF517 EX_fe3_e
# iNF517 EX_glc__D_e
# iNF517 EX_glu__L_e
# iNF517 EX_gly_e
# iNF517 EX_gua_e
# iNF517 EX_h2o_e
# iNF517 EX_h_e
# iNF517 EX_his__L_e
# iNF517 EX_ile__L_e
# iNF517 EX_ins_e
# iNF517 EX_leu__L_e
# iNF517 EX_lys__L_e
# iNF517 EX_met__L_e
# iNF517 EX_mn2_e
# iNF517 EX_nac_e
# iNF517 EX_nh4_e
# iNF517 EX_orot_e
# iNF517 EX_phe__L_e
# iNF517 EX_pi_e
# iNF517 EX_pnto__R_e
# iNF517 EX_ribflv_e
# iNF517 EX_ser__L_e
# iNF517 EX_thm_e
# iNF517 EX_thr__L_e
# iNF517 EX_thymd_e
# iNF517 EX_ura_e
# iNF517 EX_val__L_e
# iNF517 EX_xan_e
# iNF517 EX_zn2_e
# iNF517 EX_2aeppn_e_i 1e-300
# iNF517 EX_2h3mb_e_i 1e-300
# iNF517 EX_2h3mp_e_i 1e-300
# iNF517 EX_2hxic__L_e_i 1e-300
# iNF517 EX_2mba_e_i 1e-300
# iNF517 EX_2mbald_e_i 1e-300
# iNF517 EX_2mpa_e_i 1e-300
# iNF517 EX_3mba_e_i 1e-300
# iNF517 EX_3mbal_e_i 1e-300
# iNF517 EX_4abut_e_i 1e-300
# iNF517 EX_4abz_e_i 0.00999
# iNF517 EX_acald_e_i 1e-300
# iNF517 EX_acgala_e_i 1e-300
# iNF517 EX_acgam_e_i 1e-300
# iNF517 EX_acmana_e_i 1e-300
# iNF517 EX_actn__R_e_i 1e-300
# iNF517 EX_ade_e_i 0.01014
# iNF517 EX_akg_e_i 1e-300
# iNF517 EX_ala__D_e_i 1e-300
# iNF517 EX_ala__L_e_i 0.04
# iNF517 EX_arg__L_e_i 0.02
# iNF517 EX_asn__L_e_i 1e-300
# iNF517 EX_asp__L_e_i 0.01
# iNF517 EX_btd_RR_e_i 1e-300
# iNF517 EX_bzal_e_i 1e-300
# iNF517 EX_cellb_e_i 1e-300
# iNF517 EX_ch4s_e_i 1e-300
# iNF517 EX_chol_e_i 1e-300
# iNF517 EX_cit_e_i 1e-300
# iNF517 EX_co2_e_i 1000.0
# iNF517 EX_cys__L_e_i 0.02
# iNF517 EX_dha_e_i 1e-300
# iNF517 EX_diact_e_i 1e-300
# iNF517 EX_drib_e_i 1e-300
# iNF517 EX_fe2_e_i 1000.0
# iNF517 EX_fe3_e_i 1000.0
# iNF517 EX_fol_e_i 1e-300
# iNF517 EX_fru_e_i 1e-300
# iNF517 EX_gal_e_i 1e-300
# iNF517 EX_galt_e_i 1e-300
# iNF517 EX_gcald_e_i 1e-300
# iNF517 EX_glc__D_e_i 2.12
# iNF517 EX_glcn__D_e_i 1e-300
# iNF517 EX_gln__L_e_i 1e-300
# iNF517 EX_glu__L_e_i 0.05
# iNF517 EX_gly_e_i 0.04
# iNF517 EX_glyb_e_i 1e-300
# iNF517 EX_glyc3p_e_i 1e-300
# iNF517 EX_glyc_e_i 1e-300
# iNF517 EX_gua_e_i 0.00906
# iNF517 EX_h2o_e_i 1000.0
# iNF517 EX_h2s_e_i 1e-300
# iNF517 EX_h_e_i 1000.0
# iNF517 EX_his__L_e_i 0.01
# iNF517 EX_hxan_e_i 1e-300
# iNF517 EX_ile__L_e_i 0.05
# iNF517 EX_ins_e_i 0.00255
# iNF517 EX_lcts_e_i 1e-300
# iNF517 EX_leu__L_e_i 0.06
# iNF517 EX_lys__L_e_i 0.04
# iNF517 EX_mal__L_e_i 1e-300
# iNF517 EX_malt_e_i 1e-300
# iNF517 EX_man_e_i 1e-300
# iNF517 EX_met__D_e_i 1e-300
# iNF517 EX_met__L_e_i 0.01
# iNF517 EX_mn2_e_i 1000.0
# iNF517 EX_mnl_e_i 1e-300
# iNF517 EX_nac_e_i 0.00111
# iNF517 EX_nh4_e_i 0.59
# iNF517 EX_nmn_e_i 1e-300
# iNF517 EX_o2_e_i 1e-300
# iNF517 EX_orn__L_e_i 1e-300
# iNF517 EX_orot_e_i 0.00439
# iNF517 EX_pacald_e_i 1e-300
# iNF517 EX_pea_e_i 1e-300
# iNF517 EX_phe__L_e_i 0.02
# iNF517 EX_pi_e_i 1000.0
# iNF517 EX_pnto__R_e_i 0.00062
# iNF517 EX_ppi_e_i 1e-300
# iNF517 EX_ptrc_e_i 1e-300
# iNF517 EX_pyr_e_i 1e-300
# iNF517 EX_rib__D_e_i 1e-300
# iNF517 EX_ribflv_e_i 0.00036
# iNF517 EX_sbt__D_e_i 1e-300
# iNF517 EX_ser__D_e_i 1e-300
# iNF517 EX_ser__L_e_i 0.11
# iNF517 EX_so4_e_i 1e-300
# iNF517 EX_spmd_e_i 1e-300
# iNF517 EX_succ_e_i 1e-300
# iNF517 EX_sucr_e_i 1e-300
# iNF517 EX_thm_e_i 0.00041
# iNF517 EX_thr__L_e_i 0.06
# iNF517 EX_thymd_e_i 0.00283
# iNF517 EX_tre_e_i 1e-300
# iNF517 EX_tyr__L_e_i 1e-300
# iNF517 EX_ura_e_i 0.01222
# iNF517 EX_val__L_e_i 0.05
# iNF517 EX_xan_e_i 0.00901
# iNF517 EX_zn2_e_i 1000.0
# 0.04263460544337314

# %% [markdown]
# ## Generating training sets

# %% [markdown]
# ### From experimental data set

# %%
# Generate training set with experimental dataset

from Library.Import import *
from Library.Build_Dataset import TrainingSet, get_index_from_id
DIRECTORY = './Dataset_input/Covid/'

# What you can change
seed = 10
np.random.seed(seed=seed)  # seed for random number generator
cobraname = 'COVIDkoEXP_duplicated'  # name of the model
mediumname = 'COVIDkoEXP'  # name of the medium file
method = 'EXP'  # FBA, pFBA or EXP
reduce = False  # Set at True if you want to reduce the model
# End of What you can change

# Get parameters from medium file
cobrafile = f'{DIRECTORY}{cobraname}'
mediumfile = f'{DIRECTORY}{mediumname}'
parameter = TrainingSet(cobraname=cobrafile,
                        mediumname=mediumfile,
                        method=method,
                        verbose=False)

trainingfile = f'{DIRECTORY}{mediumname}'
parameter.save(trainingfile, reduce=reduce)

# Verifying
parameter = TrainingSet()
parameter.load(trainingfile)
print(trainingfile)
parameter.printout()

# %% [markdown]
# ### From FBA simulated data

# %%
# Create a FBA simulated training for various species

from Library.Import import *
from Library.Build_Dataset import TrainingSet, get_objective, get_minmed_varmed_ko
import matplotlib.pyplot as plt
import cobra

DIRECTORY = './Dataset_input/'

from Library.Utilities import *
from Library.Build_Dataset import TrainingSet

seed = 10
np.random.seed(seed=seed)  
size = 10000
ratmed =  28 # max nbr of variable media turned on biolog 127 Paul 28

species = [ 
    'e_coli_core', #0
    'iEK1008', 
    'iIT341', #2
    'iJN1463', 
    'iML1515', #4
    'iMM904',
    'iPC815', #6
    'iYO844',
    'iYS1720', 
    'iYS854', # 9
    'iCN718',
    'iNF517',
    'iML1515EXP'
]

for i in [ 11 ]:
    name = species[i]    
    method = 'EXP' if 'EXP' in name else 'FBA'
    # Get data
    cobrafile = f'{DIRECTORY}{name}_duplicated'
    mediumfile  = f'{DIRECTORY}{name}'
    parameter = TrainingSet(cobraname=cobrafile, 
                            mediumname=mediumfile, 
                            method=method,
                            ratmed=ratmed,
                            verbose=True)

    # Build training set
    if method == 'FBA':
        parameter.X = np.asarray([]).reshape(0, 0)
        parameter.Y = np.asarray([]).reshape(0, 0)
        parameter.size = 0
        minmed, varmed, ko = get_minmed_varmed_ko(parameter.medium)
        parameter.get(sample_size=size, verbose=False)

    # Saving file
    trainingfile = f'{DIRECTORY}{name}_train'
    parameter.save(trainingfile, reduce=False)

    # Verifying
    parameter = TrainingSet()
    parameter.load(trainingfile)
    parameter.printout()
# Out:
5), 'EX_cobalt2_e_i': (1.0, 6.5), 'EX_cu2_e_i': (1.0, 6.5), 'EX_fe2_e_i': (1.0, 6.5), 'EX_fe3_e_i': (1.0, 6.5), 'EX_h_e_i': (1.0, 6.5), 'EX_h2o_e_i': (1.0, 6.5), 'EX_k_e_i': (1.0, 6.5), 'EX_mg2_e_i': (1.0, 6.5), 'EX_mn2_e_i': (1.0, 6.5), 'EX_mobd_e_i': (1.0, 6.5), 'EX_na1_e_i': (1.0, 6.5), 'EX_nh4_e_i': (1.0, 6.5), 'EX_ni2_e_i': (1.0, 6.5), 'EX_o2_e_i': (1.0, 6.5), 'EX_pi_e_i': (1.0, 6.5), 'EX_sel_e_i': (1.0, 6.5), 'EX_slnt_e_i': (1.0, 6.5), 'EX_so4_e_i': (1.0, 6.5), 'EX_tungs_e_i': (1.0, 6.5), 'EX_zn2_e_i': (1.0, 6.5), 'EX_glc__D_e_i': (100.0, 6.5), 'EX_xyl__D_e_i': (100.0, 6.5), 'EX_succ_e_i': (100.0, 6.5), 'EX_ala__L_e_i': (100.0, 6.5), 'EX_arg__L_e_i': (100.0, 6.5), 'EX_asn__L_e_i': (100.0, 6.5), 'EX_asp__L_e_i': (100.0, 6.5), 'EX_cys__L_e_i': (100.0, 6.5), 'EX_glu__L_e_i': (100.0, 6.5), 'EX_gln__L_e_i': (100.0, 6.5), 'EX_gly_e_i': (100.0, 6.5), 'EX_his__L_e_i': (100.0, 6.5), 'EX_ile__L_e_i': (100.0, 6.5), 'EX_leu__L_e_i': (100.0, 6.5), 'EX_lys__L_e_i': (100.0, 6.5), 'EX_met__L_e_i': (100.0, 6.5), 'EX_phe__L_e_i': (100.0, 6.5), 'EX_pro__L_e_i': (100.0, 6.5), 'EX_ser__L_e_i': (100.0, 6.5), 'EX_thr__L_e_i': (100.0, 6.5), 'EX_trp__L_e_i': (100.0, 6.5), 'EX_tyr__L_e_i': (100.0, 6.5), 'EX_val__L_e_i': (100.0, 6.5), 'EX_ade_e_i': (100.0, 6.5), 'EX_gua_e_i': (100.0, 6.5), 'EX_csn_e_i': (100.0, 6.5), 'EX_ura_e_i': (100.0, 6.5), 'EX_thymd_e_i': (100.0, 6.5)}
# len medium: 115
# ratmed: 28
# method: FBA
# X: (0, 28)
# Y: (0, 0)
# objective: ['BIOMASS_LLA']
# measurements size: 1079
# -----------------------------./Dataset_input/iNF517_duplicated sample: 0 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 100 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 200 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 300 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 400 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 500 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 600 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 700 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 800 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 900 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 1000 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 1100 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 1200 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 1300 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 1400 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 1500 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 1600 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 1700 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 1800 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 1900 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 2000 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 2100 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 2200 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 2300 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 2400 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 2500 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 2600 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 2700 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 2800 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 2900 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 3000 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 3100 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 3200 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 3300 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 3400 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 3500 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 3600 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 3700 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 3800 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 3900 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 4000 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 4100 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 4200 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 4300 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 4400 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 4500 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 4600 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 4700 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 4800 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 4900 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 5000 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 5100 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 5200 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 5300 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 5400 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 5500 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 5600 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 5700 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 5800 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 5900 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 6000 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 6100 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 6200 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 6300 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 6400 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 6500 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 6600 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 6700 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 6800 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 6900 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 7000 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 7100 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 7200 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 7300 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 7400 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 7500 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 7600 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 7700 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 7800 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 7900 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 8000 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 8100 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 8200 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 8300 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 8400 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 8500 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 8600 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 8700 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 8800 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 8900 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 9000 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 9100 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 9200 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 9300 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 9400 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 9500 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 9600 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 9700 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 9800 -----------------------------
# -----------------------------./Dataset_input/iNF517_duplicated sample: 9900 -----------------------------
# model file name: ./Dataset_input/iNF517_train
# reduced model: False
# medium file name: ./Dataset_input/iNF517
# medium: 115
# experimental medium: 0
# list of reactions in objective: ['BIOMASS_LLA']
# method: FBA
# trainingsize: 10000
# list of measured reactions: 1079
# Stoichiometric matrix: (650, 1079)
# Boundary matrix from reactions to medium: (28, 1079)
# KO matrix from reactions to ko: (0, 1079)
# Measurement matrix from reaction to measures: (1079, 1079)
# Training set X: (10000, 28)
# Training set Y: (10000, 1079)

# %%
# Create a FBA simulated training for Covid data: iML1515 with KOs

from Library.Import import *
from Library.Build_Dataset import TrainingSet, get_objective, get_minmed_varmed_ko

DIRECTORY = './Dataset_input/Covid/'

from Library.Utilities import *

seed = 10
np.random.seed(seed=seed)  
size = 10000
ratmed = 56 # all variable variable MS signals

name = 'Covid'
KOs = ['WT', 'hisD', 'proC', 'serC', 'tyrA', 'trpA', 'pheA']

for ko in KOs:  
    method = 'FBA'
    # Get data
    cobrafile = f'{DIRECTORY}{name}_duplicated'
    mediumfile  = f'{DIRECTORY}{name}'
    parameter = TrainingSet(cobraname=cobrafile, 
                            mediumname=mediumfile, 
                            method=method,
                            ratmed=ratmed,
                            verbose=False)

    # Build training set
    parameter.X = np.asarray([]).reshape(0, 0)
    parameter.Y = np.asarray([]).reshape(0, 0)
    parameter.size = 0
    minmed, varmed, _ = get_minmed_varmed_ko(parameter.medium)
    parameter.get(sample_size=size,
                  genekos=[ko],
                  cobra_min_objective=1.0e-3,
                  cobra_max_objective=3.0,
                  verbose=False)
    
    # Saving file
    trainingfile = f'{DIRECTORY}{name}_{ko}_train'
    parameter.save(trainingfile, reduce=False)

    # Verifying
    parameter = TrainingSet()
    parameter.load(trainingfile)
    parameter.printout()
    parameter.filter_measure(measure=[get_objective(parameter.model)])
    Y_obj = parameter.Y
    print(f'Min {np.min(Y_obj):.3f} '
          f'Max {np.max(Y_obj):.3f} '
          f'Med {np.median(Y_obj):.3f} '
          f'Avr {np.mean(Y_obj):.3f} for {ko}')
# Out:
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 0 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 8000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 8100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 8200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 8300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 8400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 8500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 8600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 8700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 8800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 8900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9900 -----------------------------
# model file name: ./Dataset_input/Covid/Covid_WT_train
# reduced model (min flux): False
# medium file name: ./Dataset_input/Covid/Covid
# medium: 80
# experimental medium: 0
# list of reactions in objective: ['BIOMASS_Ec_iML1515_core_75p37M']
# method: FBA
# trainingsize: 10000
# list of measured reactions: 3682
# Stoichiometric matrix: (1877, 3682)
# Boundary matrix from reactions to medium: (56, 3682)
# KO matrix from reactions to ko: (0, 3682)
# Measurement matrix from reaction to measures: (3682, 3682)
# Training set X: (10000, 56)
# Training set Y: (10000, 3682)
# Min 0.001 Max 1.171 Med 0.388 Avr 0.409 for WT
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 0 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 0 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 0 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 8000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 8100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 8200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 8300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 8300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 8400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 8400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 8400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 8400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 8500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 8600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 8700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 8700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 8700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 8800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 8900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 9900 -----------------------------
# model file name: ./Dataset_input/Covid/Covid_hisD_train
# reduced model (min flux): False
# medium file name: ./Dataset_input/Covid/Covid
# medium: 80
# experimental medium: 0
# list of reactions in objective: ['BIOMASS_Ec_iML1515_core_75p37M']
# method: FBA
# trainingsize: 10000
# list of measured reactions: 3682
# Stoichiometric matrix: (1877, 3682)
# Boundary matrix from reactions to medium: (56, 3682)
# KO matrix from reactions to ko: (0, 3682)
# Measurement matrix from reaction to measures: (3682, 3682)
# Training set X: (10000, 56)
# Training set Y: (10000, 3682)
# Min 0.001 Max 1.245 Med 0.547 Avr 0.536 for hisD
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 0 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 1900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 2900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 3900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 4900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 5900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6700 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6800 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 6900 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7000 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7200 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7300 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7400 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7500 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7600 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 7700 -----------------------------

# %% [markdown]
# ### From FBA simulated data constrained by experimental data

# %%
# Generate training set with E coli iML1515 with FBA simulation
# constrained by experimental file: metabolites in medium are not drawn at
# random but are the same than in the provided training experimental file
# This cell may take several hours to execute! Avoid running this in Colab

DIRECTORY = './Dataset_input/'

from Library.Import import *
from Library.Build_Dataset import TrainingSet, get_index_from_id

# Parameters
seed = 10
np.random.seed(seed=seed)  # seed for random number generator
name = 'iML1515EXP'  # name of the model
cobrafile = f'{DIRECTORY}{name}_duplicated'
mediumfile  = f'{DIRECTORY}{name}'
method = 'FBA'  # FBA, pFBA or EXP
size_i = 10  # expname training set size, training set size per item in expname
reduce = False  # Set at True if you want to reduce the model

# Get parameters from medium file
parameter = TrainingSet(cobraname=cobrafile,
                        mediumname=mediumfile,
                        method=method,
                        verbose=False)
parameter.printout()

# Reset media data prior building training set
X, Y, size = parameter.X, parameter.Y, parameter.X.shape[0]
parameter.X = np.asarray([]).reshape(0, 0)
parameter.Y = np.asarray([]).reshape(0, 0)
parameter.size = 0

# Get a Cobra training set constrained by experimental_medium
biomass_id = get_index_from_id('BIOMASS_Ec_iML1515_core_75p37M', parameter.model.reactions)
print(f'biomass_id: {biomass_id}')
for i in range(size):
    parameter.get(sample_size=size_i, 
                  mediumexp=parameter.mediumexp[i],
                  verbose=False)
    biomass_mean = np.mean(parameter.Y[i * size_i:, biomass_id])
    biomass_min = np.min(parameter.Y[i * size_i:, biomass_id])
    biomass_max = np.max(parameter.Y[i * size_i:, biomass_id])
    if biomass_max < Y[i, 0]:
        status = 'NEG'
    elif biomass_min > Y[i, 0]:
        status = 'POS'
    else:
        status = 'GOOD'
    print(f'Medium {i:3d} {len(parameter.mediumexp[i]):2d} '
          f'Biomass-Mean {biomass_mean:.3f} ' 
          f'Min {biomass_min:.3f} Max {biomass_max:.3f} '
          f'Target {Y[i, 0]:.3f} in-range {status}')

# Saving file
size = parameter.X.shape[0]
trainingfile = f'{DIRECTORY}{name}_{str(size)}_train'
parameter.save(trainingfile, reduce=reduce)

# Verifying
parameter = TrainingSet()
parameter.load(trainingfile)
print(trainingfile)
parameter.printout()
# Out:
# model file name: ./Dataset_input/iML1515EXP_duplicated
# reduced model: False
# medium file name: ./Dataset_input/iML1515EXP
# medium: 51
# experimental medium: 280
# list of reactions in objective: ['BIOMASS_Ec_iML1515_core_75p37M']
# method: FBA
# trainingsize: 280
# list of measured reactions: 3682
# Stoichiometric matrix: (1877, 3682)
# Boundary matrix from reactions to medium: (28, 3682)
# KO matrix from reactions to ko: (0, 3682)
# Measurement matrix from reaction to measures: (3682, 3682)
# Training set X: (280, 28)
# Training set Y: (280, 1)
# biomass_id: 2668
# -----------------------------./Dataset_input/iML1515EXP_duplicated sample: 0 -----------------------------
# Medium   0  1 Biomass-Mean 0.188 Min 0.021 Max 0.325 Target 0.488 in-range NEG
# -----------------------------./Dataset_input/iML1515EXP_duplicated sample: 0 -----------------------------
# Medium   1 26 Biomass-Mean 0.637 Min 0.443 Max 0.780 Target 1.046 in-range NEG
# -----------------------------./Dataset_input/iML1515EXP_duplicated sample: 0 -----------------------------

# %%
# Generate training set with E coli iML1515 using Covid data with FBA simulation

from Library.Import import *
from Library.Build_Dataset import TrainingSet, get_index_from_id, get_minmed_varmed_ko
DIRECTORY = './Dataset_input/Covid/'

# What you can change
seed = 10
np.random.seed(seed=seed)  # seed for random number generator
cobraname = 'Covid_duplicated'  # name of the model
mediumname = 'Covid_EXP'  # name of the medium file
method = 'FBA'  # FBA, pFBA or EXP
size_i = 1000  # expname training set size, training set size per item in expname
treshold = 0.05
reduce = False  # Set at True if you want to reduce the model
# End of What you can change

# Get parameters from medium file
cobrafile = f'{DIRECTORY}{cobraname}'
mediumfile = f'{DIRECTORY}{mediumname}'
parameter = TrainingSet(cobraname=cobrafile,
                        mediumname=mediumfile,
                        method=method,
                        verbose=False)
parameter.printout()

# Reset media data prior building training set
X, Y, Nko, size = parameter.X, parameter.Y[:,0].reshape(-1,1), parameter.Y[:,1], parameter.X.shape[0]
parameter.X = np.asarray([]).reshape(0, 0)
parameter.Y = np.asarray([]).reshape(0, 0)
parameter.size = 0

KOs = ['WT  ', 'hisD', 'proC', 'serC', 'tyrA', 'trpA', 'pheA']

# Get a Cobra training set constrained by experimental_medium
biomass_id = get_index_from_id('BIOMASS_Ec_iML1515_core_75p37M', parameter.model.reactions)
print(f'biomass_id: {biomass_id}')
for i in range(size):
    parameter.get(sample_size=size_i, 
                  mediumexp=parameter.mediumexp[i],
                  genekos=[KOs[int(Nko[i])]],
                  verbose=False)
    y, t = parameter.Y[i * size_i:, biomass_id], Y[i, 0]
    X = parameter.X[i * size_i:,:] 
    dy = np.abs(y - t)
    k = np.argmin(dy)
    biomass_mean, biomass_min, biomass_max = np.mean(y), np.min(y), np.max(y)
    if biomass_max < Y[i, 0]:
        status = 'NEG'
    elif biomass_min > Y[i, 0]:
        status = 'POS'
    else:
        status = 'GOOD'
    print(f'KO {KOs[int(Nko[i])]} Medium {i:d} {len(parameter.mediumexp[i]):2d} '
          f'Biomass-Mean {biomass_mean:.3f} ' 
          f'Min {biomass_min:.3f} Max {biomass_max:.3f} '
          f'Closest {y[k]:3f} Target {t:.3f} argmin {k} ' 
          f'distance-min {dy[k]:.4f} in-range {status}')

    # Search and print the best media
    xx = np.array2string(X[k], formatter={'float_kind':lambda x: '%.3f' % x})
    print(xx.replace('\n','').replace('[','').replace(']',''), t, y[k])

    for kk in range(dy.shape[0]):
        if dy[kk] < treshold:
            xx = np.array2string(X[kk], formatter={'float_kind':lambda x: '%.3f' % x})
            print(xx.replace('\n','').replace('[','').replace(']',''), t, y[kk])

"""
# Saving file
size = parameter.X.shape[0]
trainingfile = f'{DIRECTORY}{mediumname}_{size}'
parameter.save(trainingfile, reduce=reduce)

# Verifying
parameter = TrainingSet()
parameter.load(trainingfile)
print(trainingfile)
parameter.printout()
"""
# Out:
# model file name: ./Dataset_input/Covid/Covid_duplicated
# reduced model: False
# medium file name: ./Dataset_input/Covid/Covid_EXP
# medium: 80
# experimental medium: 14
# list of reactions in objective: ['BIOMASS_Ec_iML1515_core_75p37M']
# method: FBA
# trainingsize: 14
# list of measured reactions: 3682
# Stoichiometric matrix: (1877, 3682)
# Boundary matrix from reactions to medium: (56, 3682)
# KO matrix from reactions to ko: (0, 3682)
# Measurement matrix from reaction to measures: (3682, 3682)
# Training set X: (14, 56)
# Training set Y: (14, 2)
# biomass_id: 2668
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 0 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 100 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample:
# 1.480 2.240 2.280 1.920 0.160 2.040 1.960 3.440 0.360 0.560 2.560 1.800 0.920 2.600 3.960 2.360 2.520 2.600 1.840 3.560 1.880 3.280 3.720 1.360 3.000 1.480 0.600 3.480 3.120 1.960 3.040 2.760 2.120 2.000 0.120 0.440 3.160 3.840 1.000 3.840 2.080 3.320 2.240 0.920 3.360 0.600 2.920 0.040 2.120 3.640 1.960 1.280 2.760 0.520 3.480 1.640 0.60284381 0.6472382202939815
# 2.160 1.680 1.400 4.000 1.880 1.200 0.880 0.480 1.880 1.240 2.880 0.760 0.200 3.720 0.600 0.440 3.720 0.720 3.120 0.200 1.480 2.760 2.360 1.040 3.160 3.760 4.000 1.720 3.280 3.240 0.720 0.720 2.000 1.920 0.440 0.240 2.720 3.640 1.920 2.800 1.240 2.680 1.280 0.840 3.520 1.880 2.440 0.960 2.960 1.560 2.080 3.480 1.320 2.440 3.400 0.680 0.60284381 0.595892306410925
# 0.640 2.320 3.440 1.080 0.400 2.240 1.000 0.000 3.320 2.080 1.280 0.280 0.560 2.200 1.880 1.880 0.160 2.040 1.000 2.600 2.840 1.320 3.360 2.520 1.480 0.400 0.520 1.000 2.040 2.520 0.200 2.920 3.160 0.880 0.520 1.480 2.200 0.400 2.360 3.680 3.880 3.560 0.000 3.760 1.040 2.000 2.960 0.440 1.640 2.120 3.800 2.920 0.240 0.360 4.000 0.000 0.60284381 0.6225220439243732
# 3.360 1.840 3.800 1.440 1.400 0.520 0.600 0.120 1.600 2.880 0.000 1.880 1.560 3.080 2.840 0.800 3.080 0.200 0.720 3.440 2.680 0.680 0.280 2.320 2.080 1.960 1.400 0.080 2.240 2.400 0.640 3.640 1.160 0.440 0.000 0.680 1.040 1.120 0.120 2.600 3.240 1.600 2.840 2.360 3.320 0.680 0.400 1.560 1.680 1.360 2.440 0.360 0.800 0.920 2.040 3.000 0.60284381 0.6455719899699718
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 0 -----------------------------
# -----------------------------./Dataset_input/Covid/Covid_duplicated sample: 100 -----------------------------

# %% [markdown]
# # Entropy plots

# %%
from Library.Import import *
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import fcluster, linkage
from sklearn.decomposition import PCA

def getY(filename):
    """
    Return all Y and Y for objective
    Parameters:
    File path
    Returns:
    Y_all, Y_obj (np.array): Arrays of Y values.
    """
    from Library.Build_Dataset import TrainingSet, get_objective
    
    # Read and return Y 
    parameter = TrainingSet()
    parameter.load(filename)
    Y_all = np.copy(parameter.Y)
    parameter.filter_measure(measure=[get_objective(parameter.model)])
    Y_obj = parameter.Y
    
    return Y_all, Y_obj 

def compute_shannon_entropy(cluster_counts):
    """
    Computes the Shannon entropy of the cluster distribution.
    Parameters:
    cluster_counts (pd.Series): Counts of elements in each cluster.
    Returns:
    float: Shannon entropy of the distribution.
    """
    total_elements = cluster_counts.sum()
    probabilities = cluster_counts / total_elements
    entropy = -np.sum(probabilities * np.log2(probabilities))
    return entropy

def cluster(Y, distance_threshold):
    """
    Clusters the Y values based on a distance threshold after optional dimensionality reduction.

    Parameters:
    Y (np.array): Array of Y values.
    distance_threshold (float): The distance threshold for clustering.

    Returns:
    tuple: Cluster labels for each point in Y, adjusted distance threshold, number of clusters, and Shannon entropy.
    """
    if Y.shape[1] > 1:
        # Compute average number of non-null values per row
        size = np.mean(np.count_nonzero(Y, axis=1))
        #pca = PCA(n_components=1)  # Reduce dimensions to 1 for clustering
        #Y_reduced = pca.fit_transform(Y)
        Y_reduced  = np.sum(Y, axis=1).reshape(-1, 1) / size
        print(Y_reduced.shape)
    else:
        size = Y.shape[1]
        Y_reduced = Y
    
    Z = linkage(Y_reduced, method='ward')
    clusters = fcluster(Z, distance_threshold, criterion='distance')
    
    df = pd.DataFrame(Y)
    df['Cluster'] = clusters
    cluster_counts = df['Cluster'].value_counts().sort_index()
    
    num_clusters = len(cluster_counts)
    entropy = compute_shannon_entropy(cluster_counts)
    
    return size, clusters, distance_threshold, num_clusters, entropy

def plot_clusters(Y, clusters, file_path, distance_threshold, adjusted_threshold, color):
    """
    Plots a bar plot of the clustered Y values.
    Parameters:
    Y (np.array): Array of Y values.
    clusters (np.array): Cluster labels for each point in Y.
    file_path (str): Path to the file containing Y values.
    distance_threshold (float): The distance threshold for clustering.
    adjusted_threshold (float): The adjusted distance threshold for clustering.
    color (str): Color for the bars in the plot.
    """
    print(f"File: {file_path} size: {Y.shape}")
    if Y.shape[1] > 1:
        print(f"Threshold (Precision): {distance_threshold:.2f} Adjusted Threshold: {adjusted_threshold:.2f}")
    else:
        print(f"Threshold (Precision): {distance_threshold:.2f}")
    
    df = pd.DataFrame(Y)
    df['Cluster'] = clusters
    cluster_counts = df['Cluster'].value_counts().sort_index()

    num_clusters = len(cluster_counts)
    entropy = compute_shannon_entropy(cluster_counts)

    print(f"Number of clusters: {num_clusters}")
    print(f"Shannon entropy: {entropy:.4f}")

    # For each cluster, compute the mean vector
    cluster_means = df.groupby('Cluster').mean()

    bins = cluster_means.index
    dis = cluster_counts

    plt.figure(figsize=(12, 8))
    if Y.shape[1] == 1:
        tick_labels = [f'{mean[0]:.2f}' for mean in cluster_means.values]
    else:
        tick_labels = [f'Cluster {i}' for i in bins]
    
    plt.bar(bins, dis, color=color, tick_label=tick_labels)
    plt.xlabel('Average Y values for clusters' if Y.shape[1] == 1 else 'Clusters')
    plt.ylabel('Number of elements in cluster')
    plt.title(f"Cluster {file_path}")
    
    # Adjust y-axis to log scale
    plt.yscale('log')
    
    # Adjust tick labels to avoid overlap
    plt.xticks(rotation=90)
    
    # Limit the number of x-tick labels displayed
    if num_clusters > 20:
        step = max(1, num_clusters // 20)
        visible_ticks = np.arange(0, num_clusters, step)
        plt.gca().set_xticks(visible_ticks)
        plt.gca().set_xticklabels([tick_labels[i] for i in visible_ticks])
    
    plt.tight_layout()
    plt.show()

from Library.Utilities import *
from Library.Build_Dataset import TrainingSet, get_objective
import matplotlib.pyplot as plt
DIRECTORY = './Dataset_input/'

seed = 1
np.random.seed(seed=seed)  
species = [ 
    'e_coli_core', #0
    'iEK1008', 
    'iIT341', #2
    'iJN1463', 
    'iML1515', #4
    'iMM904',
    'iPC815', #6
    'iYO844',
    'iYS1720', 
    'iYS854', # 9
    'iCN718',
    'iNF517',
    'iML1515EXP' # 12
]
precision = 0.01
results = []
plotting = False

for i in list(range(12)): 
    name = species[i]
    print(name)
    # Get data
    filename = f'{name}_train'
    trainingfile = f'{DIRECTORY}{filename}'
    Y_all, Y_obj = getY(trainingfile)
    
    # Clustering for Y_obj
    size_obj, clusters_obj, adjusted_threshold_obj, num_clusters_obj, entropy_obj = cluster(Y_obj, precision)
    if plotting:
        plot_clusters(Y_obj, clusters_obj, f'{name}_Y_obj', precision, adjusted_threshold_obj, color='cyan')
    
    # Clustering for Y_all
    size_all, clusters_all, adjusted_threshold_all, num_clusters_all, entropy_all = cluster(Y_all, precision)
    if plotting:
        plot_clusters(Y_all, clusters_all, f'{name}_Y_all', precision, adjusted_threshold_all, color='orange')
    
    results.append((name, size_obj, adjusted_threshold_obj, num_clusters_obj, entropy_obj, size_all, adjusted_threshold_all, num_clusters_all, entropy_all))

# Print summary after plotting all curves for all files
print("\nSummary:")
print("File Name,Size(obj),Threshold(Y_obj),Clusters(Y_obj),Entropy(Y_obj),Size(all),Threshold(Y_all),Clusters(Y_all),Entropy(Y_all)")
for result in results:
    name, size_obj, adjusted_threshold_obj, num_clusters_obj, entropy_obj, size_all, adjusted_threshold_all, num_clusters_all, entropy_all = result
    print(f"{name},{size_obj},{adjusted_threshold_obj:.2f},{num_clusters_obj},{entropy_obj:.4f},{size_all},{adjusted_threshold_all:.2f},{num_clusters_all},{entropy_all:.4f}")
# Out:
# e_coli_core
# (10000, 1)
# iEK1008
# (10000, 1)
# iIT341
# (10000, 1)
# iJN1463
# (10000, 1)
# iML1515
# (500, 1)
# iMM904
# (10000, 1)
# iPC815
# (10000, 1)
# iYO844
# (10000, 1)
# iYS1720
# (10000, 1)
# iYS854
# (10000, 1)
# iCN718
# (10000, 1)
# iNF517
# (10000, 1)
#
# Summary:
# File Name,Size(obj),Threshold(Y_obj),Clusters(Y_obj),Entropy(Y_obj),Size(all),Threshold(Y_all),Clusters(Y_all),Entropy(Y_all)
# e_coli_core,1,0.01,8,2.7113,51.9413,0.01,53,3.7451
# iEK1008,1,0.01,122,6.5623,473.5062,0.01,370,8.2311
# iIT341,1,0.01,140,5.2601,308.2361,0.01,303,7.1050
# iJN1463,1,0.01,176,7.0302,607.6669,0.01,277,7.8844
# iML1515,1,0.01,101,6.4724,448.9,0.01,272,7.9030
# iMM904,1,0.01,216,7.4888,288.9085,0.01,693,9.3287
# iPC815,1,0.01,294,7.8259,377.0682,0.01,551,8.8676
# iYO844,1,0.01,180,7.2270,331.4583,0.01,588,8.6993
# iYS1720,1,0.01,364,8.2992,430.9575,0.01,1318,9.9860
# iYS854,1,0.01,607,8.9376,541.0579,0.01,867,9.5249
# iCN718,1,0.01,110,6.3612,304.7148,0.01,1059,9.5954
# iNF517,1,0.01,220,7.5784,374.5864,0.01,397,8.2097
